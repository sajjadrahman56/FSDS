# %%
import logging
import os

# %%
log_dir = "logs"
log_file_name = "app.log"

# %%
os.makedirs(log_dir, exist_ok=True)
log_path = os.path.join(log_dir, log_file_name)
print(log_path)
# Out:
# logs\app.log

# %%
logging.basicConfig(filename=log_path,
                    format='[%(asctime)s] %(name)s - %(levelname)s - %(message)s',
                    level=logging.INFO)

# %%
def myself(name):
    if type(name) == str:
        print(f"My name is {name}")
    else:
        logging.info("Name must be a string")

# %%
myself("Sajjad")
# Out:
# My name is Sajjad

# %%
myself(56)

# %%
try:
    with open("files/samina.txt","r") as f:
        data = f.read()
        print(data)

except Exception as e:
    logging.info(e)
