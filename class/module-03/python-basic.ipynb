# %%
print("The new year new journey start")
# Out:
# The new year new journey start

# %% [markdown]
# A function is a mechanism that performs a specific task.
# <br>

# %%
# It shows error , as we know for defining string we have to use multiple commands
print("sajjad)
# Out:
#   Cell In[2], line 2
#     print("sajjad)
#           ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
# print() is a very powerful functions 

print("Abir",1,3.6,7*8,0,True)
# Out:
# Abir 1 3.6 56 0 True

# %%
# change the sep 

print("Abir",1,3.6,7*8,0,True,sep='_')
# Out:
# Abir_1_3.6_56_0_True

# %%
print("Bangladesh")
print("is a Country ")
# Out:
# Bangladesh
# is a Country

# %%
# we can control it like this below 
print("Bangladesh" , end=" [] ")
print("is a Country ")

# newline is by default , so we can handel it
# Out:
# Bangladesh [] is a Country

# %% [markdown]
# ## Python Data type
# ---
# 1. Integer
# 2. Float
# 3. Boolen
# 4. String
# 5. Complex
# 6. List
# 7. Tuple
# 8. Sets
# 9. Dictionary

# %% [markdown]
# ### Variable 2 types
#
# - Dynamic Typing
# - Static Typing

# %%
# Dynamic Typing 
a = 7
type(a)

# Static Typing 

ab1 : int  = 8;

type(ab1)

ab1 : str = "sajjad"

# %%
y : int = 10

y = "01-data-types.md"

print(y)
# Out:
# 01-data-types.md
